# %%
import warnings
import uxarray as ux
import holoviews as hv
import cartopy.crs as ccrs

hv.extension("bokeh")
warnings.filterwarnings("ignore")

era5_inic_file = '/glade/derecho/scratch/nforcone/betacast_ERA5ml_20200810.nc'
hrrr_inic_file = '/glade/derecho/scratch/nforcone/betacast_HRRRml_20200810.nc'
grid_path = '/glade/u/home/nforcone/MidwestVarRes/midwest-06-16-2025_edit22_ESMF.nc'
# grid_path = '/glade/u/home/nforcone/MidwestVarRes/midwest-06-16-2025_edit22_np4_SCRIP.nc'
exodus = '/glade/u/home/nforcone/MidwestVarRes/midwest-06-16-2025_edit22.g'
uxds_with_exodus = ux.open_dataset(exodus, hrrr_inic_file)

ERA5_uxds = ux.open_dataset(grid_path, era5_inic_file)
HRRR_uxds = ux.open_dataset(grid_path, hrrr_inic_file)

HRRR_uxds['T'][0][0].plot()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='721d1c46-9a04-4565-bab9-54319e96a351'>
#   <div id="ab4a5692-78cd-48ac-8135-485143bce0d2" data-root-id="721d1c46-9a04-4565-bab9-54319e96a351" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
ERA5_uxds['T'][0][0].plot(cmap='plasma', projection=ccrs.Orthographic(central_longitude=-120))
# Out:
# :Image   [Longitude,Latitude]   (Longitude_Latitude T)
